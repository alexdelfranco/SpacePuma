# %%
# %matplotlib widget
import sys; sys.path.append('src')
import main_menu as mn

# %%
import numpy as np
x = np.arange(100); y = np.exp(-1/2 * (((x-50)/10) ** 2))
y[:60] += np.copy(y[25:85]); y[40:] += np.copy(y[15:75])

# %%
base = mn.main_menu(data=[x,y])
# Out:
# HBox(children=(ToggleButton(value=True, description='On', layout=Layout(width='45px')), ToggleButton(value=Fal…
# Output()
# HBox()
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
